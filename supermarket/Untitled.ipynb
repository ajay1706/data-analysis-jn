# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
import xlrd
df3 = pandas.read_excel("supermarkets.xlsx",sheet_name= 0)
df3
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df5 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6= pandas.read_csv("data.txt",header=None)
df6
# Out:
#    0                  1                2                  3     4  \
# 0  1       3666 21st St   San Francisco            CA 94114   USA
# 1  2    735  Dolored St    San Francisco           CA 94119   USA
# 2  3        332 Hill St    San Francisco   California 94114   USA
# 3  4       3995 23rd st    San Francisco           CA 94114   USA
# 4  5    1056 Sanchez St    San Francisco         California   USA
# 5  6   551 Alvarado St     San Francisco           CA 94114   USA
#
#                 5   6
# 0         Madeira   8
# 1     Bready Shop  15
# 2     Super river  25
# 3   Ben\'92s Shop  10
# 4         Sanchez  12
# 5      Richvalley  20

# %%
df6.columns = ["ID","Address","City","ZIP","Country","Name","Employees"]
df6
# Out:
#    ID            Address             City                ZIP Country  \
# 0   1       3666 21st St   San Francisco            CA 94114     USA
# 1   2    735  Dolored St    San Francisco           CA 94119     USA
# 2   3        332 Hill St    San Francisco   California 94114     USA
# 3   4       3995 23rd st    San Francisco           CA 94114     USA
# 4   5    1056 Sanchez St    San Francisco         California     USA
# 5   6   551 Alvarado St     San Francisco           CA 94114     USA
#
#              Name  Employees
# 0         Madeira          8
# 1     Bready Shop         15
# 2     Super river         25
# 3   Ben\'92s Shop         10
# 4         Sanchez         12
# 5      Richvalley         20

# %%
df6.set_index("ID")
# Out:
#               Address             City                ZIP Country  \
# ID
# 1        3666 21st St   San Francisco            CA 94114     USA
# 2     735  Dolored St    San Francisco           CA 94119     USA
# 3         332 Hill St    San Francisco   California 94114     USA
# 4        3995 23rd st    San Francisco           CA 94114     USA
# 5     1056 Sanchez St    San Francisco         California     USA
# 6    551 Alvarado St     San Francisco           CA 94114     USA
#
#               Name  Employees
# ID
# 1          Madeira          8
# 2      Bready Shop         15
# 3      Super river         25
# 4    Ben\'92s Shop         10
# 5          Sanchez         12
# 6       Richvalley         20

# %%
df7 =df6.set_index("ID")

# %%
df7
# Out:
#               Address             City                ZIP Country  \
# ID
# 1        3666 21st St   San Francisco            CA 94114     USA
# 2     735  Dolored St    San Francisco           CA 94119     USA
# 3         332 Hill St    San Francisco   California 94114     USA
# 4        3995 23rd st    San Francisco           CA 94114     USA
# 5     1056 Sanchez St    San Francisco         California     USA
# 6    551 Alvarado St     San Francisco           CA 94114     USA
#
#               Name  Employees
# ID
# 1          Madeira          8
# 2      Bready Shop         15
# 3      Super river         25
# 4    Ben\'92s Shop         10
# 5          Sanchez         12
# 6       Richvalley         20

# %%
df8 =pandas.read_json("http://pythonhow.com/supermarkets.json")

# %%
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8 = df8.set_index("Address")

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.loc["735 Dolores St": "332 Hill St", "ID":"Country"]
# Out:
#                 ID           City             State Country
# Address
# 735 Dolores St   2  San Francisco          CA 94119     USA
# 332 Hill St      3  San Francisco  California 94114     USA

# %%
df8.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
list(df8.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.iloc[:,:]
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.iloc[1,1:4]
# Out:
# City       San Francisco
# State           CA 94119
# Country              USA
# Name: 735 Dolores St, dtype: object

# %%
df8.iloc[1,0:4]
# Out:
# ID                     2
# City       San Francisco
# State           CA 94119
# Country              USA
# Name: 735 Dolores St, dtype: object

# %%
df8.drop("City",1)
# Out:
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.drop("735 Dolores St",0)
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.drop(df8.index[0:3],0)
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df8.drop(df8.columns[0:3],1)
# Out:
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8["Continent"]=df8.shape[0]*["North America"]

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df8.shape
# Out:
# (6, 7)

# %%
df8.shape[0]*["North America"]
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
df8["Continent"]= df8["Country"]+ ','+ ' North America'

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 332 Hill St             25  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
df8
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 332 Hill St             25  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
df8_t = df8.T

# %%
df8_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df8_t["My Address"] = [7,"My City","My State","My Country","My Shop",10,"My Continent"]

# %%
df8_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df8=df8_t.T

# %%
df8
# Out:
#                 ID           City             State     Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119         USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114         USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California         USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114         USA   Richvalley
# My Address       7        My City          My State  My Country      My Shop
#
#                 Employees           Continent
# Address
# 3666 21st St            8  USA, North America
# 735 Dolores St         15  USA, North America
# 332 Hill St            25  USA, North America
# 3995 23rd St           10  USA, North America
# 1056 Sanchez St        12  USA, North America
# 551 Alvarado St        20  USA, North America
# ...

# %%
df8_t["332 Hill St"] = [7,"My City","My State","My Country","My Shop",10,"My Continent"]

# %%
df8
# Out:
#                 ID           City             State     Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119         USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114         USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California         USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114         USA   Richvalley
# My Address       7        My City          My State  My Country      My Shop
#
#                 Employees           Continent
# Address
# 3666 21st St            8  USA, North America
# 735 Dolores St         15  USA, North America
# 332 Hill St            25  USA, North America
# 3995 23rd St           10  USA, North America
# 1056 Sanchez St        12  USA, North America
# 551 Alvarado St        20  USA, North America
# ...

# %%
df8 = df8_t.T

# %%
df8
# Out:
#                 ID           City       State     Country         Name  \
# Address
# 3666 21st St     1  San Francisco    CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco    CA 94119         USA  Bready Shop
# 332 Hill St      7        My City    My State  My Country      My Shop
# 3995 23rd St     4  San Francisco    CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco  California         USA      Sanchez
# 551 Alvarado St  6  San Francisco    CA 94114         USA   Richvalley
# My Address       7        My City    My State  My Country      My Shop
#
#                 Employees           Continent
# Address
# 3666 21st St            8  USA, North America
# 735 Dolores St         15  USA, North America
# 332 Hill St            10        My Continent
# 3995 23rd St           10  USA, North America
# 1056 Sanchez St        12  USA, North America
# 551 Alvarado St        20  USA, North America
# My Address             10        My Continent

# %%
type(df8)
# Out:
# pandas.core.frame.DataFrame

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()
